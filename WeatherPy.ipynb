# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | visnes
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | mount isa
# Processing Record 9 of Set 1 | mogadishu
# Processing Record 10 of Set 1 | fougamou
# Processing Record 11 of Set 1 | makat
# Processing Record 12 of Set 1 | aklavik
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | aripuana
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | lorengau
# Processing Record 17 of Set 1 | asau
# Processing Record 18 of Set 1 | udachnyy
# Processing Record 19 of Set 1 | nome
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | comodoro rivadavia
# Processing Record 22 of Set 1 | colquechaca
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | kapuskasing
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | hosangadi
# Processing Record 31 of Set 1 | krasnovishersk
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | puerto el triunfo
# Processing Record 37 of Set 1 | sobolevo
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | ouahigouya
# Processing Record 41 of Set 1 | troitskoye
# Processing Record 42 of Set 1 | constitucion
# Processing Record 43 of Set 1 | lavumisa
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | victoria
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | aguas formosas
# Processing Record 49 of Set 1 | langenburg
# Processing Record 50 of Set 1 | santa fe
# Processing Record 1 of Set 2 | husavik
# Processing Record 2 of Set 2 | lasa
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | polunochnoye
# Processing Record 7 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 8 of Set 2 | aksu
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | koslan
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | saint george
# Processing Record 14 of Set 2 | omboue
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | te anau
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | byron bay
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | acajutla
# Processing Record 24 of Set 2 | westport
# Processing Record 25 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 2 | longyearbyen
# Processing Record 27 of Set 2 | olafsvik
# Processing Record 28 of Set 2 | borogontsy
# Processing Record 29 of Set 2 | lensk
# Processing Record 30 of Set 2 | plouzane
# Processing Record 31 of Set 2 | nanticoke
# Processing Record 32 of Set 2 | sovetskiy
# Processing Record 33 of Set 2 | carbonia
# Processing Record 34 of Set 2 | rikitea
# Processing Record 35 of Set 2 | nantucket
# Processing Record 36 of Set 2 | cayenne
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | shubarshi
# Processing Record 39 of Set 2 | geraldton
# Processing Record 40 of Set 2 | sunrise manor
# Processing Record 41 of Set 2 | broken hill
# Processing Record 42 of Set 2 | coronado
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | cedar city
# Processing Record 45 of Set 2 | hunfeld
# Processing Record 46 of Set 2 | mango
# Processing Record 47 of Set 2 | lumut
# Processing Record 48 of Set 2 | dudinka
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | bar harbor
# Processing Record 1 of Set 3 | flong
# Processing Record 2 of Set 3 | metehara
# City not found. Skipping...
# Processing Record 3 of Set 3 | tautira
# Processing Record 4 of Set 3 | alamogordo
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | henties bay
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | vanderhoof
# Processing Record 9 of Set 3 | chifeng
# Processing Record 10 of Set 3 | alofi
# Processing Record 11 of Set 3 | pangoa
# Processing Record 12 of Set 3 | labuhan
# Processing Record 13 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 3 | faanui
# Processing Record 15 of Set 3 | berlevag
# Processing Record 16 of Set 3 | andros
# Processing Record 17 of Set 3 | povenets
# Processing Record 18 of Set 3 | kota kinabalu
# Processing Record 19 of Set 3 | bintulu
# Processing Record 20 of Set 3 | bontang
# Processing Record 21 of Set 3 | grootfontein
# Processing Record 22 of Set 3 | rio grande
# Processing Record 23 of Set 3 | tilichiki
# Processing Record 24 of Set 3 | port hawkesbury
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | kupino
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | tarko-sale
# Processing Record 30 of Set 3 | kuryk
# Processing Record 31 of Set 3 | iwanai
# Processing Record 32 of Set 3 | puerto leguizamo
# Processing Record 33 of Set 3 | kondinskoye
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | balykshi
# Processing Record 36 of Set 3 | okhotsk
# Processing Record 37 of Set 3 | healesville
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | gondanglegi
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | uvat
# Processing Record 42 of Set 3 | tateyama
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | port hueneme
# Processing Record 45 of Set 3 | salvador
# Processing Record 46 of Set 3 | bluff
# Processing Record 47 of Set 3 | chabua
# Processing Record 48 of Set 3 | wukari
# Processing Record 49 of Set 3 | biharamulo
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | bucerias
# Processing Record 2 of Set 4 | bulawayo
# Processing Record 3 of Set 4 | port hardy
# Processing Record 4 of Set 4 | vila vicosa
# Processing Record 5 of Set 4 | staryy nadym
# Processing Record 6 of Set 4 | olden
# Processing Record 7 of Set 4 | suzun
# Processing Record 8 of Set 4 | kiama
# Processing Record 9 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 4 | leningradskiy
# Processing Record 11 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 4 | kikwit
# Processing Record 13 of Set 4 | diffa
# Processing Record 14 of Set 4 | buta
# Processing Record 15 of Set 4 | kayerkan
# Processing Record 16 of Set 4 | vanersborg
# Processing Record 17 of Set 4 | martapura
# Processing Record 18 of Set 4 | umm kaddadah
# Processing Record 19 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 4 | guerrero negro
# Processing Record 21 of Set 4 | lazaro cardenas
# Processing Record 22 of Set 4 | meadow lake
# Processing Record 23 of Set 4 | rocha
# Processing Record 24 of Set 4 | sandwick
# Processing Record 25 of Set 4 | kupang
# Processing Record 26 of Set 4 | pathein
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | bure
# Processing Record 30 of Set 4 | zhigansk
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | laguna
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | beipiao
# Processing Record 35 of Set 4 | soe
# Processing Record 36 of Set 4 | caravelas
# Processing Record 37 of Set 4 | kruisfontein
# Processing Record 38 of Set 4 | lishu
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | inzhavino
# Processing Record 41 of Set 4 | sriperumbudur
# Processing Record 42 of Set 4 | chicama
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | illela
# Processing Record 45 of Set 4 | norman wells
# Processing Record 46 of Set 4 | narsaq
# Processing Record 47 of Set 4 | paamiut
# Processing Record 48 of Set 4 | saldanha
# Processing Record 49 of Set 4 | itigi
# Processing Record 50 of Set 4 | clyde river
# Processing Record 1 of Set 5 | lodja
# Processing Record 2 of Set 5 | jumla
# Processing Record 3 of Set 5 | muzhi
# Processing Record 4 of Set 5 | wana
# Processing Record 5 of Set 5 | mayo
# Processing Record 6 of Set 5 | yellapur
# Processing Record 7 of Set 5 | cabo rojo
# Processing Record 8 of Set 5 | rena
# Processing Record 9 of Set 5 | kimbe
# Processing Record 10 of Set 5 | kapaa
# Processing Record 11 of Set 5 | pimenta bueno
# Processing Record 12 of Set 5 | ruwi
# Processing Record 13 of Set 5 | orsha
# Processing Record 14 of Set 5 | itaituba
# Processing Record 15 of Set 5 | lata
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | ust-kuyga
# Processing Record 18 of Set 5 | hudson bay
# Processing Record 19 of Set 5 | guicheng
# City not found. Skipping...
# Processing Record 20 of Set 5 | nikolskoye
# Processing Record 21 of Set 5 | san giustino
# Processing Record 22 of Set 5 | prado
# Processing Record 23 of Set 5 | flin flon
# Processing Record 24 of Set 5 | pacifica
# Processing Record 25 of Set 5 | barwani
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | atuona
# Processing Record 29 of Set 5 | rizhao
# Processing Record 30 of Set 5 | massakory
# Processing Record 31 of Set 5 | launceston
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | san remo
# Processing Record 34 of Set 5 | presidencia roque saenz pena
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | meulaboh
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | cidreira
# Processing Record 41 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 5 | beloha
# Processing Record 43 of Set 5 | mabaruma
# Processing Record 44 of Set 5 | naron
# Processing Record 45 of Set 5 | bambous virieux
# Processing Record 46 of Set 5 | port lincoln
# Processing Record 47 of Set 5 | tarakan
# Processing Record 48 of Set 5 | tambura
# Processing Record 49 of Set 5 | awjilah
# Processing Record 50 of Set 5 | hyeres
# Processing Record 1 of Set 6 | ciudad bolivar
# Processing Record 2 of Set 6 | charters towers
# Processing Record 3 of Set 6 | bata
# Processing Record 4 of Set 6 | barcelos
# Processing Record 5 of Set 6 | ulverstone
# Processing Record 6 of Set 6 | grua
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | new norfolk
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | miami
# Processing Record 12 of Set 6 | morondava
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | upernavik
# Processing Record 15 of Set 6 | paita
# Processing Record 16 of Set 6 | los llanos de aridane
# Processing Record 17 of Set 6 | marevo
# Processing Record 18 of Set 6 | hualmay
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | cap-aux-meules
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | hammerfest
# Processing Record 23 of Set 6 | chulman
# Processing Record 24 of Set 6 | turukhansk
# Processing Record 25 of Set 6 | marzuq
# Processing Record 26 of Set 6 | correntina
# Processing Record 27 of Set 6 | ancud
# Processing Record 28 of Set 6 | taltal
# Processing Record 29 of Set 6 | sahuaripa
# Processing Record 30 of Set 6 | berdigestyakh
# Processing Record 31 of Set 6 | casas grandes
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | katha
# City not found. Skipping...
# Processing Record 34 of Set 6 | neuquen
# Processing Record 35 of Set 6 | pasni
# Processing Record 36 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 6 | ashtabula
# Processing Record 38 of Set 6 | ribeira brava
# Processing Record 39 of Set 6 | santa maria
# Processing Record 40 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 6 | adrar
# Processing Record 42 of Set 6 | phayakkhaphum phisai
# Processing Record 43 of Set 6 | filingue
# Processing Record 44 of Set 6 | toamasina
# Processing Record 45 of Set 6 | sao joao da barra
# Processing Record 46 of Set 6 | sambava
# Processing Record 47 of Set 6 | usinsk
# Processing Record 48 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 6 | hukuntsi
# Processing Record 50 of Set 6 | lebu
# Processing Record 1 of Set 7 | la ronge
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | cooma
# Processing Record 4 of Set 7 | arica
# Processing Record 5 of Set 7 | batagay-alyta
# Processing Record 6 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 7 of Set 7 | oranjemund
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | tiksi
# Processing Record 10 of Set 7 | pangnirtung
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | cockburn town
# Processing Record 13 of Set 7 | viedma
# Processing Record 14 of Set 7 | nobeoka
# Processing Record 15 of Set 7 | vila
# Processing Record 16 of Set 7 | nuuk
# Processing Record 17 of Set 7 | dunedin
# Processing Record 18 of Set 7 | idrinskoye
# Processing Record 19 of Set 7 | atar
# Processing Record 20 of Set 7 | monteagudo
# Processing Record 21 of Set 7 | chuy
# Processing Record 22 of Set 7 | virginia beach
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | sibu
# Processing Record 25 of Set 7 | channel-port aux basques
# Processing Record 26 of Set 7 | xai-xai
# Processing Record 27 of Set 7 | maragogi
# Processing Record 28 of Set 7 | dourbali
# Processing Record 29 of Set 7 | chara
# Processing Record 30 of Set 7 | dicabisagan
# Processing Record 31 of Set 7 | gornyatskiy
# Processing Record 32 of Set 7 | jalapa
# Processing Record 33 of Set 7 | duobao
# Processing Record 34 of Set 7 | nishihara
# Processing Record 35 of Set 7 | katsuura
# Processing Record 36 of Set 7 | ambilobe
# Processing Record 37 of Set 7 | ambon
# Processing Record 38 of Set 7 | isangel
# Processing Record 39 of Set 7 | talnakh
# Processing Record 40 of Set 7 | tuktoyaktuk
# Processing Record 41 of Set 7 | progreso
# Processing Record 42 of Set 7 | parana
# Processing Record 43 of Set 7 | wajir
# Processing Record 44 of Set 7 | camopi
# Processing Record 45 of Set 7 | greeneville
# Processing Record 46 of Set 7 | bambanglipuro
# Processing Record 47 of Set 7 | lewistown
# Processing Record 48 of Set 7 | yaan
# Processing Record 49 of Set 7 | biggar
# Processing Record 50 of Set 7 | orlik
# Processing Record 1 of Set 8 | tracy
# Processing Record 2 of Set 8 | acapulco
# Processing Record 3 of Set 8 | celestun
# Processing Record 4 of Set 8 | shangzhi
# Processing Record 5 of Set 8 | moses lake
# Processing Record 6 of Set 8 | bayanday
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | west wendover
# Processing Record 9 of Set 8 | oussouye
# Processing Record 10 of Set 8 | kidal
# Processing Record 11 of Set 8 | bonthe
# Processing Record 12 of Set 8 | port blair
# Processing Record 13 of Set 8 | hirado
# Processing Record 14 of Set 8 | nouadhibou
# Processing Record 15 of Set 8 | kartuzy
# Processing Record 16 of Set 8 | nzega
# Processing Record 17 of Set 8 | santiago del estero
# Processing Record 18 of Set 8 | araouane
# Processing Record 19 of Set 8 | necochea
# Processing Record 20 of Set 8 | warmbad
# Processing Record 21 of Set 8 | kosikha
# Processing Record 22 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 8 | mackay
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | bilma
# Processing Record 26 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | san cristobal
# Processing Record 29 of Set 8 | jutai
# Processing Record 30 of Set 8 | mezhdurechensk
# Processing Record 31 of Set 8 | cam ranh
# Processing Record 32 of Set 8 | klaksvik
# Processing Record 33 of Set 8 | grindavik
# Processing Record 34 of Set 8 | pingliang
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | aleksandrov gay
# Processing Record 37 of Set 8 | srednekolymsk
# Processing Record 38 of Set 8 | ustyuzhna
# Processing Record 39 of Set 8 | kericho
# Processing Record 40 of Set 8 | tlaltenango
# Processing Record 41 of Set 8 | contamana
# Processing Record 42 of Set 8 | talara
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | saint-denis
# Processing Record 45 of Set 8 | vrangel
# Processing Record 46 of Set 8 | manggar
# Processing Record 47 of Set 8 | dongning
# Processing Record 48 of Set 8 | kemlya
# Processing Record 49 of Set 8 | vangaindrano
# Processing Record 50 of Set 8 | mangan
# Processing Record 1 of Set 9 | mount gambier
# Processing Record 2 of Set 9 | manono
# Processing Record 3 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 9 | waipawa
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | bengkulu
# Processing Record 7 of Set 9 | ebano
# City not found. Skipping...
# Processing Record 8 of Set 9 | clarence town
# Processing Record 9 of Set 9 | san rafael
# Processing Record 10 of Set 9 | lubao
# Processing Record 11 of Set 9 | kamenka
# Processing Record 12 of Set 9 | iquique
# Processing Record 13 of Set 9 | esso
# Processing Record 14 of Set 9 | taoudenni
# Processing Record 15 of Set 9 | uglich
# Processing Record 16 of Set 9 | kindu
# Processing Record 17 of Set 9 | tabas
# Processing Record 18 of Set 9 | ishigaki
# Processing Record 19 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 9 | coquimbo
# Processing Record 21 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 9 | svetlogorsk
# Processing Record 23 of Set 9 | jos
# Processing Record 24 of Set 9 | rumuruti
# Processing Record 25 of Set 9 | tessalit
# Processing Record 26 of Set 9 | natal
# Processing Record 27 of Set 9 | kysyl-syr
# Processing Record 28 of Set 9 | vilyuysk
# Processing Record 29 of Set 9 | otane
# Processing Record 30 of Set 9 | nave
# Processing Record 31 of Set 9 | jurm
# Processing Record 32 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 9 | leeton
# Processing Record 34 of Set 9 | villa del rosario
# Processing Record 35 of Set 9 | gazojak
# Processing Record 36 of Set 9 | varnavino
# Processing Record 37 of Set 9 | aksarka
# Processing Record 38 of Set 9 | esna
# Processing Record 39 of Set 9 | siaya
# Processing Record 40 of Set 9 | malkangiri
# Processing Record 41 of Set 9 | san juan
# Processing Record 42 of Set 9 | mbuji-mayi
# Processing Record 43 of Set 9 | sarakhs
# Processing Record 44 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 9 | chute-aux-outardes
# Processing Record 46 of Set 9 | riyadh
# Processing Record 47 of Set 9 | eureka
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | kostomuksha
# Processing Record 50 of Set 9 | tigre
# Processing Record 1 of Set 10 | devin
# Processing Record 2 of Set 10 | beringovskiy
# Processing Record 3 of Set 10 | luau
# Processing Record 4 of Set 10 | husyatyn
# Processing Record 5 of Set 10 | buraydah
# Processing Record 6 of Set 10 | amuntai
# Processing Record 7 of Set 10 | hirara
# Processing Record 8 of Set 10 | billings
# Processing Record 9 of Set 10 | mariel
# Processing Record 10 of Set 10 | dosso
# Processing Record 11 of Set 10 | saint-louis
# Processing Record 12 of Set 10 | alta floresta
# Processing Record 13 of Set 10 | kungurtug
# Processing Record 14 of Set 10 | mikhaylovka
# Processing Record 15 of Set 10 | sri aman
# Processing Record 16 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 10 | rafaela
# Processing Record 18 of Set 10 | zlobin
# Processing Record 19 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 20 of Set 10 | faya
# Processing Record 21 of Set 10 | mapiripan
# Processing Record 22 of Set 10 | tigil
# Processing Record 23 of Set 10 | krasnogvardeyskiy
# Processing Record 24 of Set 10 | lagoa
# Processing Record 25 of Set 10 | san isidro
# Processing Record 26 of Set 10 | presidente epitacio
# Processing Record 27 of Set 10 | victoria point
# Processing Record 28 of Set 10 | teseney
# Processing Record 29 of Set 10 | palmer
# Processing Record 30 of Set 10 | jaguey grande
# Processing Record 31 of Set 10 | guadalupe y calvo
# Processing Record 32 of Set 10 | kedrovyy
# Processing Record 33 of Set 10 | verkhnetulomskiy
# Processing Record 34 of Set 10 | safford
# Processing Record 35 of Set 10 | matola
# Processing Record 36 of Set 10 | dongzhen
# Processing Record 37 of Set 10 | gat
# Processing Record 38 of Set 10 | burns lake
# Processing Record 39 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 10 | mountain home
# Processing Record 41 of Set 10 | fukue
# Processing Record 42 of Set 10 | bairiki
# Processing Record 43 of Set 10 | shingu
# Processing Record 44 of Set 10 | sibolga
# Processing Record 45 of Set 10 | nagato
# Processing Record 46 of Set 10 | nemuro
# Processing Record 47 of Set 10 | gallup
# Processing Record 48 of Set 10 | ossora
# Processing Record 49 of Set 10 | harper
# Processing Record 50 of Set 10 | phuntsholing
# Processing Record 1 of Set 11 | lakota
# Processing Record 2 of Set 11 | jinxiang
# Processing Record 3 of Set 11 | verkhoyansk
# Processing Record 4 of Set 11 | carnarvon
# Processing Record 5 of Set 11 | osmena
# Processing Record 6 of Set 11 | cortez
# Processing Record 7 of Set 11 | bakchar
# Processing Record 8 of Set 11 | batemans bay
# Processing Record 9 of Set 11 | ventspils
# Processing Record 10 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | deniliquin
# Processing Record 12 of Set 11 | yar-sale
# Processing Record 13 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 11 | den chai
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | warrington
# Processing Record 17 of Set 11 | ubauro
# Processing Record 18 of Set 11 | bereda
# Processing Record 19 of Set 11 | gulfport
# Processing Record 20 of Set 11 | stantsionno-oyashinskiy
# Processing Record 21 of Set 11 | pochutla
# Processing Record 22 of Set 11 | straumen
# Processing Record 23 of Set 11 | catemaco
# Processing Record 24 of Set 11 | ceres
# Processing Record 25 of Set 11 | haines junction
# Processing Record 26 of Set 11 | belaya gora
# Processing Record 27 of Set 11 | leon
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | matara
# Processing Record 30 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 11 | marfino
# Processing Record 32 of Set 11 | namibe
# Processing Record 33 of Set 11 | maua
# Processing Record 34 of Set 11 | grafton
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | ada
# Processing Record 37 of Set 11 | calvia
# Processing Record 38 of Set 11 | valdivia
# Processing Record 39 of Set 11 | katiola
# Processing Record 40 of Set 11 | takoradi
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | abalak
# Processing Record 43 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | grand gaube
# Processing Record 46 of Set 11 | dingle
# Processing Record 47 of Set 11 | puerto cabezas
# Processing Record 48 of Set 11 | santa rosa
# Processing Record 49 of Set 11 | maniitsoq
# Processing Record 50 of Set 11 | roald
# Processing Record 1 of Set 12 | zilair
# Processing Record 2 of Set 12 | matane
# Processing Record 3 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 12 | thinadhoo
# Processing Record 5 of Set 12 | agadez
# Processing Record 6 of Set 12 | saint anthony
# Processing Record 7 of Set 12 | yarada
# Processing Record 8 of Set 12 | halifax
# Processing Record 9 of Set 12 | namatanai
# Processing Record 10 of Set 12 | galesong
# Processing Record 11 of Set 12 | lac-megantic
# Processing Record 12 of Set 12 | sharan
# Processing Record 13 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 12 | peniche
# Processing Record 15 of Set 12 | morant bay
# Processing Record 16 of Set 12 | nanortalik
# Processing Record 17 of Set 12 | lompoc
# Processing Record 18 of Set 12 | lampazos de naranjo
# Processing Record 19 of Set 12 | vaasa
# Processing Record 20 of Set 12 | dongtai
# Processing Record 21 of Set 12 | wadi
# Processing Record 22 of Set 12 | sisimiut
# Processing Record 23 of Set 12 | akureyri
# Processing Record 24 of Set 12 | kralendijk
# Processing Record 25 of Set 12 | kabelvag
# Processing Record 26 of Set 12 | gornopravdinsk
# Processing Record 27 of Set 12 | andarab
# City not found. Skipping...
# Processing Record 28 of Set 12 | sawtell
# Processing Record 29 of Set 12 | toora-khem
# Processing Record 30 of Set 12 | alenquer
# Processing Record 31 of Set 12 | tevaitoa
# Processing Record 32 of Set 12 | zlatarica
# City not found. Skipping...
# Processing Record 33 of Set 12 | alyangula
# Processing Record 34 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 12 | marrakesh
# Processing Record 36 of Set 12 | hamilton
# Processing Record 37 of Set 12 | guia de isora
# Processing Record 38 of Set 12 | marawi
# Processing Record 39 of Set 12 | teya
# Processing Record 40 of Set 12 | tuatapere
# Processing Record 41 of Set 12 | valleyview
# Processing Record 42 of Set 12 | keti bandar
# Processing Record 43 of Set 12 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 44 of Set 12 | arlit
# Processing Record 45 of Set 12 | angoche
# Processing Record 46 of Set 12 | morgan city
# Processing Record 47 of Set 12 | mucuri
# Processing Record 48 of Set 12 | visby
# Processing Record 49 of Set 12 | sangar
# Processing Record 50 of Set 12 | banda aceh
# Processing Record 1 of Set 13 | gao
# Processing Record 2 of Set 13 | baykit
# Processing Record 3 of Set 13 | sur
# Processing Record 4 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 5 of Set 13 | senador jose porfirio
# Processing Record 6 of Set 13 | vestmannaeyjar
# Processing Record 7 of Set 13 | sitka
# Processing Record 8 of Set 13 | coos bay
# Processing Record 9 of Set 13 | nakusp
# Processing Record 10 of Set 13 | lircay
# Processing Record 11 of Set 13 | broome
# Processing Record 12 of Set 13 | malacacheta
# Processing Record 13 of Set 13 | dali
# Processing Record 14 of Set 13 | buin
# Processing Record 15 of Set 13 | puksoozero
# Processing Record 16 of Set 13 | nalut
# Processing Record 17 of Set 13 | newton
# Processing Record 18 of Set 13 | rio brilhante
# Processing Record 19 of Set 13 | gunjur
# Processing Record 20 of Set 13 | waingapu
# Processing Record 21 of Set 13 | magadan
# Processing Record 22 of Set 13 | zenzeli
# Processing Record 23 of Set 13 | spencer
# Processing Record 24 of Set 13 | chapais
# Processing Record 25 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 26 of Set 13 | kavaratti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Lavrentiya  65.5833 -171.0000     27.72        86         100
# 1         Tasiilaq  65.6145  -37.6368     27.36        78          93
# 2           Visnes  59.3556    5.2242     49.82        46           0
# 3     Puerto Ayora  -0.7393  -90.3518     71.31        92          44
# 4  Arraial Do Cabo -22.9661  -42.0278     76.35        86           1
# 5           Hobart -42.8794  147.3294     68.22        60          20
# 6        Jamestown  42.0970  -79.2353     63.18        57           0
# 7        Mount Isa -20.7333  139.5000     78.57        73         100
# 8        Mogadishu   2.0371   45.3438     85.28        66          31
# 9         Fougamou  -1.2154   10.5838     73.40        98         100
#
#    Wind Speed Country                 Date
# 0        2.68      RU  2022-04-24 06:05:25
# 1        7.20      GL  2022-04-24 06:05:26
# 2       11.50      NO  2022-04-24 06:05:26
# 3        6.40      EC  2022-04-24 06:03:05
# 4        7.72      BR  2022-04-24 06:05:27
# 5       11.50      AU  2022-04-24 06:03:27
# 6        6.91      US  2022-04-24 06:05:27
# 7        6.91      AU  2022-04-24 06:01:27
# 8       12.28      SO  2022-04-24 06:05:28
# 9        1.66      GA  2022-04-24 06:05:28

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 578     True
# 579     True
# 580     True
# 581     True
# 582     True
# Name: Lat, Length: 583, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0    Lavrentiya      RU  2022-04-24 06:05:25  65.5833 -171.0000     27.72
# 1      Tasiilaq      GL  2022-04-24 06:05:26  65.6145  -37.6368     27.36
# 2        Visnes      NO  2022-04-24 06:05:26  59.3556    5.2242     49.82
# 6     Jamestown      US  2022-04-24 06:05:27  42.0970  -79.2353     63.18
# 8     Mogadishu      SO  2022-04-24 06:05:28   2.0371   45.3438     85.28
# ..          ...     ...                  ...      ...       ...       ...
# 578     Magadan      RU  2022-04-24 06:21:07  59.5667  150.8000     36.54
# 579     Zenzeli      RU  2022-04-24 06:19:15  45.9241   47.0474     60.53
# 580     Spencer      US  2022-04-24 06:21:07  43.1414  -95.1444     44.71
# 581     Chapais      CA  2022-04-24 06:17:46  49.7834  -74.8492     22.78
# 582   Kavaratti      IN  2022-04-24 06:21:08  10.5669   72.6420     84.52
#
#      Humidity  Cloudiness  Wind Speed
# 0          86         100        2.68
# 1          78          93        7.20
# 2          46           0       11.50
# 6          57           0        6.91
# 8          66          31       12.28
# ..        ...         ...         ...
# 578        64         100        2.39
# 579        52          25        7.76
# 580        61           0       13.80
# 581        91         100        4.88
# 582        70          99        2.95
#
# [409 rows x 9 columns]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0  Lavrentiya      RU  2022-04-24 06:05:25  65.5833 -171.0000     27.72
# 1    Tasiilaq      GL  2022-04-24 06:05:26  65.6145  -37.6368     27.36
# 2      Visnes      NO  2022-04-24 06:05:26  59.3556    5.2242     49.82
# 6   Jamestown      US  2022-04-24 06:05:27  42.0970  -79.2353     63.18
# 8   Mogadishu      SO  2022-04-24 06:05:28   2.0371   45.3438     85.28
#
#    Humidity  Cloudiness  Wind Speed
# 0        86         100        2.68
# 1        78          93        7.20
# 2        46           0       11.50
# 6        57           0        6.91
# 8        66          31       12.28

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                        'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

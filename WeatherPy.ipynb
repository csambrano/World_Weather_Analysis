# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | alofi
# Processing Record 3 of Set 1 | onega
# Processing Record 4 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 1 | hailar
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | nicoya
# Processing Record 8 of Set 1 | sitka
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | broome
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | mildura
# Processing Record 13 of Set 1 | marzuq
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | belmonte
# Processing Record 16 of Set 1 | vredendal
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | formosa do rio preto
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | vostok
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | keffi
# Processing Record 23 of Set 1 | chapais
# Processing Record 24 of Set 1 | aklavik
# Processing Record 25 of Set 1 | gjusvik
# City not found. Skipping...
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | marsabit
# Processing Record 30 of Set 1 | bambanglipuro
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | moose factory
# Processing Record 33 of Set 1 | darnah
# Processing Record 34 of Set 1 | andarab
# City not found. Skipping...
# Processing Record 35 of Set 1 | jiangyou
# Processing Record 36 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | kalamazoo
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | codrington
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | innisfail
# Processing Record 45 of Set 1 | dalby
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | porto velho
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | lebanon
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | ucluelet
# Processing Record 5 of Set 2 | tocopilla
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | bangassou
# Processing Record 9 of Set 2 | ryazhsk
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | windhoek
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | buraydah
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | jumla
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | adrar
# Processing Record 18 of Set 2 | bakchar
# Processing Record 19 of Set 2 | belle glade
# Processing Record 20 of Set 2 | mahajanga
# Processing Record 21 of Set 2 | northam
# Processing Record 22 of Set 2 | naze
# Processing Record 23 of Set 2 | killybegs
# Processing Record 24 of Set 2 | nosy varika
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | deputatskiy
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | olinda
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | gazli
# Processing Record 32 of Set 2 | kuusamo
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | nurota
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | talaya
# Processing Record 39 of Set 2 | husavik
# Processing Record 40 of Set 2 | methoni
# Processing Record 41 of Set 2 | mandan
# Processing Record 42 of Set 2 | coquimbo
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | lasa
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | atambua
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | bafia
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | santa maria del oro
# Processing Record 5 of Set 3 | ugoofaaru
# Processing Record 6 of Set 3 | orbetello
# Processing Record 7 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 12 of Set 3 | hobart
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | yar-sale
# Processing Record 15 of Set 3 | launceston
# Processing Record 16 of Set 3 | lompoc
# Processing Record 17 of Set 3 | beaverlodge
# Processing Record 18 of Set 3 | rincon
# Processing Record 19 of Set 3 | chokurdakh
# Processing Record 20 of Set 3 | quelimane
# Processing Record 21 of Set 3 | ayia galini
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | malanje
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | villa maria
# Processing Record 26 of Set 3 | jaen
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | chaihe
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 3 | angoram
# Processing Record 32 of Set 3 | garissa
# Processing Record 33 of Set 3 | kahului
# Processing Record 34 of Set 3 | phalombe
# Processing Record 35 of Set 3 | sterling
# Processing Record 36 of Set 3 | yulara
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | college
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | genhe
# Processing Record 41 of Set 3 | mnogovershinnyy
# Processing Record 42 of Set 3 | yaan
# Processing Record 43 of Set 3 | mtimbira
# Processing Record 44 of Set 3 | saint-pierre
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | berbera
# Processing Record 47 of Set 3 | baykalovo
# Processing Record 48 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | syracuse
# Processing Record 2 of Set 4 | itaituba
# Processing Record 3 of Set 4 | krasnoselkup
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | saint-joseph
# Processing Record 6 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | ozinki
# Processing Record 8 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 9 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 4 | alugan
# Processing Record 11 of Set 4 | bataipora
# Processing Record 12 of Set 4 | gorontalo
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | najran
# Processing Record 15 of Set 4 | kalaleh
# Processing Record 16 of Set 4 | souillac
# Processing Record 17 of Set 4 | salalah
# Processing Record 18 of Set 4 | fairbanks
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | saskylakh
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | grindavik
# Processing Record 23 of Set 4 | broken hill
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | maniitsoq
# Processing Record 26 of Set 4 | vestmannaeyjar
# Processing Record 27 of Set 4 | changji
# Processing Record 28 of Set 4 | dorogobuzh
# Processing Record 29 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 4 | palana
# Processing Record 31 of Set 4 | kaohsiung
# Processing Record 32 of Set 4 | nouakchott
# Processing Record 33 of Set 4 | batticaloa
# Processing Record 34 of Set 4 | kalomo
# City not found. Skipping...
# Processing Record 35 of Set 4 | luis correia
# Processing Record 36 of Set 4 | sao filipe
# Processing Record 37 of Set 4 | tomatlan
# Processing Record 38 of Set 4 | carauari
# Processing Record 39 of Set 4 | faya
# Processing Record 40 of Set 4 | edson
# Processing Record 41 of Set 4 | sioux lookout
# Processing Record 42 of Set 4 | qasigiannguit
# Processing Record 43 of Set 4 | port blair
# Processing Record 44 of Set 4 | hambantota
# Processing Record 45 of Set 4 | maceio
# Processing Record 46 of Set 4 | meulaboh
# Processing Record 47 of Set 4 | carnaiba
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | barsovo
# Processing Record 1 of Set 5 | ergani
# Processing Record 2 of Set 5 | mana
# Processing Record 3 of Set 5 | farafangana
# Processing Record 4 of Set 5 | burica
# City not found. Skipping...
# Processing Record 5 of Set 5 | makakilo city
# Processing Record 6 of Set 5 | hutchinson
# Processing Record 7 of Set 5 | lamu
# Processing Record 8 of Set 5 | makung
# City not found. Skipping...
# Processing Record 9 of Set 5 | necochea
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | saint-philippe
# Processing Record 12 of Set 5 | lynn haven
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | haines junction
# Processing Record 15 of Set 5 | muros
# Processing Record 16 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | fredericksburg
# Processing Record 18 of Set 5 | marienburg
# Processing Record 19 of Set 5 | mitu
# Processing Record 20 of Set 5 | villa oliva
# City not found. Skipping...
# Processing Record 21 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 5 | havre-saint-pierre
# Processing Record 24 of Set 5 | strasice
# Processing Record 25 of Set 5 | tuktoyaktuk
# Processing Record 26 of Set 5 | octeville
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | taltal
# Processing Record 29 of Set 5 | ponta do sol
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | cidreira
# Processing Record 32 of Set 5 | saint-georges
# Processing Record 33 of Set 5 | rundu
# Processing Record 34 of Set 5 | vaini
# Processing Record 35 of Set 5 | barrow
# Processing Record 36 of Set 5 | jining
# Processing Record 37 of Set 5 | chimbote
# Processing Record 38 of Set 5 | surt
# Processing Record 39 of Set 5 | lazaro cardenas
# Processing Record 40 of Set 5 | muriwai beach
# Processing Record 41 of Set 5 | magdagachi
# Processing Record 42 of Set 5 | hovd
# Processing Record 43 of Set 5 | dengzhou
# Processing Record 44 of Set 5 | cap malheureux
# Processing Record 45 of Set 5 | barra
# Processing Record 46 of Set 5 | chaman
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | namibe
# Processing Record 50 of Set 5 | ornskoldsvik
# Processing Record 1 of Set 6 | chuy
# Processing Record 2 of Set 6 | luganville
# Processing Record 3 of Set 6 | turayf
# Processing Record 4 of Set 6 | vidim
# Processing Record 5 of Set 6 | sakakah
# Processing Record 6 of Set 6 | nehe
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | diplo
# Processing Record 9 of Set 6 | batemans bay
# Processing Record 10 of Set 6 | dutse
# Processing Record 11 of Set 6 | rio claro
# Processing Record 12 of Set 6 | palmer
# Processing Record 13 of Set 6 | victor harbor
# Processing Record 14 of Set 6 | lorengau
# Processing Record 15 of Set 6 | asekeyevo
# Processing Record 16 of Set 6 | khani
# Processing Record 17 of Set 6 | ribeira grande
# Processing Record 18 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 6 | sistranda
# Processing Record 20 of Set 6 | tias
# Processing Record 21 of Set 6 | rosarito
# Processing Record 22 of Set 6 | samur
# Processing Record 23 of Set 6 | gubbi
# Processing Record 24 of Set 6 | lubyany
# Processing Record 25 of Set 6 | clyde river
# Processing Record 26 of Set 6 | itacoatiara
# Processing Record 27 of Set 6 | fare
# Processing Record 28 of Set 6 | abha
# Processing Record 29 of Set 6 | podor
# Processing Record 30 of Set 6 | baker city
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | luanda
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | cairns
# Processing Record 35 of Set 6 | guilin
# Processing Record 36 of Set 6 | ulaangom
# Processing Record 37 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | churapcha
# Processing Record 39 of Set 6 | canitas
# City not found. Skipping...
# Processing Record 40 of Set 6 | lincoln
# Processing Record 41 of Set 6 | shitanjing
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | grand bank
# Processing Record 44 of Set 6 | avarua
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | qobustan
# Processing Record 47 of Set 6 | avera
# Processing Record 48 of Set 6 | talakan
# Processing Record 49 of Set 6 | wiener neustadt
# Processing Record 50 of Set 6 | itupiranga
# Processing Record 1 of Set 7 | rawson
# Processing Record 2 of Set 7 | gunjur
# Processing Record 3 of Set 7 | mon
# Processing Record 4 of Set 7 | tsogni
# Processing Record 5 of Set 7 | evensk
# Processing Record 6 of Set 7 | gorom-gorom
# Processing Record 7 of Set 7 | mukerian
# Processing Record 8 of Set 7 | kendari
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | hammerfest
# Processing Record 11 of Set 7 | ormara
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | kaifeng
# Processing Record 14 of Set 7 | ancud
# Processing Record 15 of Set 7 | tiruchchendur
# Processing Record 16 of Set 7 | pavlodar
# Processing Record 17 of Set 7 | belaya gora
# Processing Record 18 of Set 7 | galdar
# Processing Record 19 of Set 7 | dharchula
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | laiagam
# City not found. Skipping...
# Processing Record 22 of Set 7 | ellisras
# Processing Record 23 of Set 7 | yarmouth
# Processing Record 24 of Set 7 | timaru
# Processing Record 25 of Set 7 | mataram
# Processing Record 26 of Set 7 | tadine
# Processing Record 27 of Set 7 | talcahuano
# Processing Record 28 of Set 7 | komsomolskiy
# Processing Record 29 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 31 of Set 7 | jijiang
# Processing Record 32 of Set 7 | nikel
# Processing Record 33 of Set 7 | south lake tahoe
# Processing Record 34 of Set 7 | puerto escondido
# Processing Record 35 of Set 7 | rantauprapat
# Processing Record 36 of Set 7 | vizinga
# Processing Record 37 of Set 7 | okhotsk
# Processing Record 38 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 7 | baruun-urt
# Processing Record 40 of Set 7 | kanth
# Processing Record 41 of Set 7 | sao gabriel da cachoeira
# Processing Record 42 of Set 7 | riyadh
# Processing Record 43 of Set 7 | takoradi
# Processing Record 44 of Set 7 | cozumel
# Processing Record 45 of Set 7 | bengkulu
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | buala
# Processing Record 49 of Set 7 | bloomingdale
# Processing Record 50 of Set 7 | karanja
# Processing Record 1 of Set 8 | otane
# Processing Record 2 of Set 8 | gizo
# Processing Record 3 of Set 8 | kailua
# Processing Record 4 of Set 8 | diamantino
# Processing Record 5 of Set 8 | alice springs
# Processing Record 6 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 7 of Set 8 | lata
# Processing Record 8 of Set 8 | palasa
# Processing Record 9 of Set 8 | porto seguro
# Processing Record 10 of Set 8 | mehamn
# Processing Record 11 of Set 8 | kupang
# Processing Record 12 of Set 8 | honningsvag
# Processing Record 13 of Set 8 | castro
# Processing Record 14 of Set 8 | finote selam
# Processing Record 15 of Set 8 | kloulklubed
# Processing Record 16 of Set 8 | coffs harbour
# Processing Record 17 of Set 8 | soyo
# Processing Record 18 of Set 8 | hanna
# Processing Record 19 of Set 8 | ixtapa
# Processing Record 20 of Set 8 | asilah
# Processing Record 21 of Set 8 | tromso
# Processing Record 22 of Set 8 | lubumbashi
# Processing Record 23 of Set 8 | apostolove
# Processing Record 24 of Set 8 | cabo san lucas
# Processing Record 25 of Set 8 | srednekolymsk
# Processing Record 26 of Set 8 | kodinsk
# Processing Record 27 of Set 8 | san cristobal
# Processing Record 28 of Set 8 | vranov
# Processing Record 29 of Set 8 | mirnyy
# Processing Record 30 of Set 8 | porto novo
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | touros
# Processing Record 33 of Set 8 | saldanha
# Processing Record 34 of Set 8 | thessalon
# Processing Record 35 of Set 8 | habay
# Processing Record 36 of Set 8 | azul
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | bairiki
# Processing Record 39 of Set 8 | murdochville
# Processing Record 40 of Set 8 | bereda
# Processing Record 41 of Set 8 | arlit
# Processing Record 42 of Set 8 | meadow lake
# Processing Record 43 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 8 | kongolo
# Processing Record 45 of Set 8 | tres lagoas
# Processing Record 46 of Set 8 | nome
# Processing Record 47 of Set 8 | fortuna
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | dzerzhinsk
# Processing Record 50 of Set 8 | kagadi
# Processing Record 1 of Set 9 | casas grandes
# Processing Record 2 of Set 9 | miles city
# Processing Record 3 of Set 9 | iberia
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | san jeronimo
# Processing Record 6 of Set 9 | elko
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | ardesen
# Processing Record 9 of Set 9 | bilibino
# Processing Record 10 of Set 9 | kaeo
# Processing Record 11 of Set 9 | semirom
# Processing Record 12 of Set 9 | richards bay
# Processing Record 13 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 9 | matara
# Processing Record 15 of Set 9 | karratha
# Processing Record 16 of Set 9 | rocha
# Processing Record 17 of Set 9 | sweetwater
# Processing Record 18 of Set 9 | galle
# Processing Record 19 of Set 9 | moerai
# Processing Record 20 of Set 9 | tecolutla
# Processing Record 21 of Set 9 | harper
# Processing Record 22 of Set 9 | benguela
# Processing Record 23 of Set 9 | namtsy
# Processing Record 24 of Set 9 | portland
# Processing Record 25 of Set 9 | tiznit
# Processing Record 26 of Set 9 | rumonge
# Processing Record 27 of Set 9 | prince rupert
# Processing Record 28 of Set 9 | zabol
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | sibolga
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | okitipupa
# Processing Record 33 of Set 9 | keflavik
# Processing Record 34 of Set 9 | abu kamal
# Processing Record 35 of Set 9 | xingyi
# Processing Record 36 of Set 9 | maragogi
# Processing Record 37 of Set 9 | port-cartier
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | arrecife
# Processing Record 40 of Set 9 | clifton
# Processing Record 41 of Set 9 | ocampo
# Processing Record 42 of Set 9 | east wenatchee bench
# Processing Record 43 of Set 9 | kavieng
# Processing Record 44 of Set 9 | dembi dolo
# Processing Record 45 of Set 9 | great yarmouth
# Processing Record 46 of Set 9 | huarmey
# Processing Record 47 of Set 9 | saint-augustin
# Processing Record 48 of Set 9 | san patricio
# Processing Record 49 of Set 9 | zamora
# Processing Record 50 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 10 | pangoa
# Processing Record 2 of Set 10 | san jose
# Processing Record 3 of Set 10 | kruisfontein
# Processing Record 4 of Set 10 | tessalit
# Processing Record 5 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 6 of Set 10 | la ronge
# Processing Record 7 of Set 10 | port-de-bouc
# Processing Record 8 of Set 10 | taixing
# Processing Record 9 of Set 10 | hervey bay
# Processing Record 10 of Set 10 | natal
# Processing Record 11 of Set 10 | along
# Processing Record 12 of Set 10 | port shepstone
# Processing Record 13 of Set 10 | kalmunai
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | the valley
# Processing Record 16 of Set 10 | cherskiy
# Processing Record 17 of Set 10 | gamba
# Processing Record 18 of Set 10 | ballina
# Processing Record 19 of Set 10 | kapoeta
# Processing Record 20 of Set 10 | bozoum
# Processing Record 21 of Set 10 | kamaishi
# Processing Record 22 of Set 10 | sinnamary
# Processing Record 23 of Set 10 | talara
# Processing Record 24 of Set 10 | saleilua
# City not found. Skipping...
# Processing Record 25 of Set 10 | lebedinyy
# Processing Record 26 of Set 10 | hami
# Processing Record 27 of Set 10 | hermagor
# Processing Record 28 of Set 10 | yazoo city
# Processing Record 29 of Set 10 | mahibadhoo
# Processing Record 30 of Set 10 | sao joao do paraiso
# Processing Record 31 of Set 10 | puerto quijarro
# Processing Record 32 of Set 10 | margate
# Processing Record 33 of Set 10 | xiaoweizhai
# Processing Record 34 of Set 10 | sambava
# Processing Record 35 of Set 10 | sendhwa
# Processing Record 36 of Set 10 | elizabeth city
# Processing Record 37 of Set 10 | padang
# Processing Record 38 of Set 10 | saint-francois
# Processing Record 39 of Set 10 | murgab
# Processing Record 40 of Set 10 | damietta
# Processing Record 41 of Set 10 | betania
# Processing Record 42 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 10 | diego de almagro
# Processing Record 44 of Set 10 | malartic
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | acari
# Processing Record 47 of Set 10 | labuhan
# Processing Record 48 of Set 10 | caravelas
# Processing Record 49 of Set 10 | santarem
# Processing Record 50 of Set 10 | savannah bight
# Processing Record 1 of Set 11 | chicama
# Processing Record 2 of Set 11 | itoman
# Processing Record 3 of Set 11 | novyy urengoy
# Processing Record 4 of Set 11 | nuuk
# Processing Record 5 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 6 of Set 11 | aksarayskiy
# Processing Record 7 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 11 | morgan hill
# Processing Record 10 of Set 11 | batagay-alyta
# Processing Record 11 of Set 11 | kyaukse
# Processing Record 12 of Set 11 | boyolangu
# Processing Record 13 of Set 11 | marsaxlokk
# Processing Record 14 of Set 11 | sao joao da barra
# Processing Record 15 of Set 11 | ustye
# Processing Record 16 of Set 11 | ca mau
# Processing Record 17 of Set 11 | nantucket
# Processing Record 18 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 11 | rochefort
# Processing Record 20 of Set 11 | dong hoi
# Processing Record 21 of Set 11 | muridke
# Processing Record 22 of Set 11 | shingu
# Processing Record 23 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 11 | byron bay
# Processing Record 25 of Set 11 | malakal
# Processing Record 26 of Set 11 | port hawkesbury
# Processing Record 27 of Set 11 | estremoz
# Processing Record 28 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 11 | phangnga
# Processing Record 30 of Set 11 | wschowa
# Processing Record 31 of Set 11 | esperance
# Processing Record 32 of Set 11 | tombouctou
# Processing Record 33 of Set 11 | akhmeta
# Processing Record 34 of Set 11 | sola
# Processing Record 35 of Set 11 | florianopolis
# Processing Record 36 of Set 11 | nayudupeta
# Processing Record 37 of Set 11 | zvishavane
# Processing Record 38 of Set 11 | saint anthony
# Processing Record 39 of Set 11 | aragarcas
# Processing Record 40 of Set 11 | pereira barreto
# Processing Record 41 of Set 11 | sandwick
# Processing Record 42 of Set 11 | pacific grove
# Processing Record 43 of Set 11 | chernaya kholunitsa
# Processing Record 44 of Set 11 | paamiut
# Processing Record 45 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 46 of Set 11 | morden
# Processing Record 47 of Set 11 | pleshanovo
# Processing Record 48 of Set 11 | shelburne
# Processing Record 49 of Set 11 | balabac
# Processing Record 50 of Set 11 | kalianget
# Processing Record 1 of Set 12 | mount gambier
# Processing Record 2 of Set 12 | saint george
# Processing Record 3 of Set 12 | caucaia
# Processing Record 4 of Set 12 | gravdal
# Processing Record 5 of Set 12 | mackenzie
# Processing Record 6 of Set 12 | pangody
# Processing Record 7 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 12 | male
# Processing Record 9 of Set 12 | kota belud
# Processing Record 10 of Set 12 | tuatapere
# Processing Record 11 of Set 12 | rancagua
# Processing Record 12 of Set 12 | rio de janeiro
# Processing Record 13 of Set 12 | opuwo
# Processing Record 14 of Set 12 | brigantine
# Processing Record 15 of Set 12 | xuddur
# Processing Record 16 of Set 12 | pauini
# Processing Record 17 of Set 12 | ust-tsilma
# Processing Record 18 of Set 12 | kyabe
# Processing Record 19 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 21 of Set 12 | marsh harbour
# Processing Record 22 of Set 12 | kudahuvadhoo
# Processing Record 23 of Set 12 | cayenne
# Processing Record 24 of Set 12 | tual
# Processing Record 25 of Set 12 | vanavara
# Processing Record 26 of Set 12 | dickinson
# Processing Record 27 of Set 12 | calabozo
# Processing Record 28 of Set 12 | kununurra
# Processing Record 29 of Set 12 | samashki
# Processing Record 30 of Set 12 | port augusta
# Processing Record 31 of Set 12 | flinders
# Processing Record 32 of Set 12 | san jorge
# Processing Record 33 of Set 12 | brenham
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | bubaque
# Processing Record 36 of Set 12 | barguzin
# Processing Record 37 of Set 12 | pingliang
# Processing Record 38 of Set 12 | alyangula
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | egvekinot
# Processing Record 41 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 12 | troitsko-pechorsk
# Processing Record 43 of Set 12 | lastoursville
# Processing Record 44 of Set 12 | stephenville crossing
# Processing Record 45 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 46 of Set 12 | takaka
# Processing Record 47 of Set 12 | chumikan
# Processing Record 48 of Set 12 | huilong
# Processing Record 49 of Set 12 | kerema
# Processing Record 50 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 1 of Set 13 | sosua
# Processing Record 2 of Set 13 | plettenberg bay
# Processing Record 3 of Set 13 | darhan
# Processing Record 4 of Set 13 | jinka
# Processing Record 5 of Set 13 | panalingaan
# Processing Record 6 of Set 13 | severo-yeniseyskiy
# Processing Record 7 of Set 13 | salinopolis
# Processing Record 8 of Set 13 | srandakan
# Processing Record 9 of Set 13 | gamovo
# Processing Record 10 of Set 13 | seoul
# Processing Record 11 of Set 13 | weifang
# Processing Record 12 of Set 13 | gisborne
# Processing Record 13 of Set 13 | kontagora
# Processing Record 14 of Set 13 | high level
# Processing Record 15 of Set 13 | khymchyn
# Processing Record 16 of Set 13 | sooke
# Processing Record 17 of Set 13 | lima
# Processing Record 18 of Set 13 | pilar
# Processing Record 19 of Set 13 | uyemskiy
# Processing Record 20 of Set 13 | valpacos
# Processing Record 21 of Set 13 | oistins
# Processing Record 22 of Set 13 | san juan de abajo
# Processing Record 23 of Set 13 | ambon
# Processing Record 24 of Set 13 | susanville
# Processing Record 25 of Set 13 | warrnambool
# Processing Record 26 of Set 13 | caiaponia
# Processing Record 27 of Set 13 | kostroma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Iqaluit  63.7506  -68.5145      2.93        71          20        5.75
# 1     Alofi -19.0595 -169.9187     76.89        94         100        3.44
# 2     Onega  63.9061   38.1404     42.53        79          70        5.46
# 3    Hailar  49.2000  119.7000     50.02        26         100       13.09
# 4   Ushuaia -54.8000  -68.3000     40.66        75         100        3.44
# 5    Nicoya  10.1483  -85.4520     76.51        80         100        1.12
# 6     Sitka  57.0531 -135.3300     40.30        78         100        1.48
# 7   Rikitea -23.1203 -134.9692     73.26        82         100       12.86
# 8    Broome  42.2506  -75.8330     48.85        87          75        5.99
# 9  Hermanus -34.4187   19.2345     61.81        72         100        9.69
#
#   Country                 Date
# 0      CA  2022-04-22 07:57:31
# 1      NU  2022-04-22 07:57:31
# 2      RU  2022-04-22 07:57:32
# 3      CN  2022-04-22 07:57:32
# 4      AR  2022-04-22 07:53:27
# 5      CR  2022-04-22 07:53:51
# 6      US  2022-04-22 07:57:33
# 7      PF  2022-04-22 07:57:33
# 8      US  2022-04-22 07:57:34
# 9      ZA  2022-04-22 07:57:34

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

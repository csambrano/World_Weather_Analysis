# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 783

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | kaili
# Processing Record 3 of Set 1 | panapakkam
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | norrtalje
# Processing Record 6 of Set 1 | sitka
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | tokomaru
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | dwarka
# Processing Record 14 of Set 1 | hailar
# Processing Record 15 of Set 1 | clyde river
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | ahuimanu
# Processing Record 18 of Set 1 | dikson
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | atbasar
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | santa maria
# Processing Record 29 of Set 1 | susner
# Processing Record 30 of Set 1 | shirokiy
# Processing Record 31 of Set 1 | weston
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | ponta do sol
# Processing Record 38 of Set 1 | kamenka
# Processing Record 39 of Set 1 | den helder
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | necochea
# Processing Record 43 of Set 1 | kuopio
# Processing Record 44 of Set 1 | paranaiba
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | micheweni
# Processing Record 48 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 1 | ahipara
# Processing Record 50 of Set 1 | dyersburg
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | mundo nuevo
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | mehamn
# Processing Record 7 of Set 2 | gurupi
# Processing Record 8 of Set 2 | leshukonskoye
# Processing Record 9 of Set 2 | diamantino
# Processing Record 10 of Set 2 | avera
# Processing Record 11 of Set 2 | ariquemes
# Processing Record 12 of Set 2 | santa maria del oro
# Processing Record 13 of Set 2 | brae
# Processing Record 14 of Set 2 | muscat
# Processing Record 15 of Set 2 | saanen
# Processing Record 16 of Set 2 | beringovskiy
# Processing Record 17 of Set 2 | vuktyl
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | kitui
# Processing Record 21 of Set 2 | soc trang
# Processing Record 22 of Set 2 | ciudad bolivar
# Processing Record 23 of Set 2 | curup
# Processing Record 24 of Set 2 | north platte
# Processing Record 25 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 2 | denpasar
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | verkhoyansk
# Processing Record 29 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 2 | bontang
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | itarema
# Processing Record 35 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 36 of Set 2 | labuhan
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | longyearbyen
# Processing Record 42 of Set 2 | ammon
# Processing Record 43 of Set 2 | dire dawa
# Processing Record 44 of Set 2 | port hawkesbury
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | bredasdorp
# Processing Record 47 of Set 2 | naze
# Processing Record 48 of Set 2 | angra
# City not found. Skipping...
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | mineiros
# Processing Record 1 of Set 3 | la grande
# Processing Record 2 of Set 3 | massakory
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | saint-philippe
# Processing Record 6 of Set 3 | tamiahua
# Processing Record 7 of Set 3 | batagay-alyta
# Processing Record 8 of Set 3 | svetlaya
# Processing Record 9 of Set 3 | bouca
# Processing Record 10 of Set 3 | owings mills
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | jacqueville
# Processing Record 13 of Set 3 | adrar
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | tilichiki
# Processing Record 16 of Set 3 | salinopolis
# Processing Record 17 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 3 | thinadhoo
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | waddan
# Processing Record 21 of Set 3 | molina
# Processing Record 22 of Set 3 | batticaloa
# Processing Record 23 of Set 3 | lasa
# Processing Record 24 of Set 3 | aksarka
# Processing Record 25 of Set 3 | alofi
# Processing Record 26 of Set 3 | pitea
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | erenhot
# Processing Record 29 of Set 3 | kununurra
# Processing Record 30 of Set 3 | comodoro rivadavia
# Processing Record 31 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 3 | zhigalovo
# Processing Record 33 of Set 3 | antalaha
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | madera
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | lakes entrance
# Processing Record 39 of Set 3 | howell
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | raucesti
# Processing Record 42 of Set 3 | oriximina
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | kolokani
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | boyolangu
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | channel-port aux basques
# Processing Record 50 of Set 3 | rio grande
# Processing Record 1 of Set 4 | san patricio
# Processing Record 2 of Set 4 | chifeng
# Processing Record 3 of Set 4 | atka
# City not found. Skipping...
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | huesca
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | nantucket
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | hermanus
# Processing Record 11 of Set 4 | bentiu
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | moryakovskiy zaton
# Processing Record 16 of Set 4 | altamont
# Processing Record 17 of Set 4 | puerto ayora
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | padang
# Processing Record 21 of Set 4 | alexandria
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 4 | lagoa
# Processing Record 25 of Set 4 | cabedelo
# Processing Record 26 of Set 4 | presidencia roque saenz pena
# Processing Record 27 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 4 | okmulgee
# Processing Record 29 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | dryden
# Processing Record 32 of Set 4 | deputatskiy
# Processing Record 33 of Set 4 | almaznyy
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | warrnambool
# Processing Record 36 of Set 4 | eyl
# Processing Record 37 of Set 4 | youkounkoun
# Processing Record 38 of Set 4 | birao
# Processing Record 39 of Set 4 | taoudenni
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | saint george
# Processing Record 42 of Set 4 | mount isa
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | turtkul
# City not found. Skipping...
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | crotone
# Processing Record 48 of Set 4 | sabzevar
# Processing Record 49 of Set 4 | amazar
# Processing Record 50 of Set 4 | aras
# Processing Record 1 of Set 5 | takapau
# Processing Record 2 of Set 5 | sechura
# Processing Record 3 of Set 5 | quatre cocos
# Processing Record 4 of Set 5 | barra patuca
# Processing Record 5 of Set 5 | yinchuan
# Processing Record 6 of Set 5 | kieta
# Processing Record 7 of Set 5 | raga
# Processing Record 8 of Set 5 | bengkulu
# Processing Record 9 of Set 5 | ous
# Processing Record 10 of Set 5 | vagur
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | husavik
# Processing Record 13 of Set 5 | bundaberg
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | baruun-urt
# Processing Record 16 of Set 5 | rancho palos verdes
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 5 | mantua
# Processing Record 20 of Set 5 | sao joao da barra
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | hovd
# Processing Record 23 of Set 5 | katangli
# Processing Record 24 of Set 5 | sorland
# Processing Record 25 of Set 5 | wanning
# Processing Record 26 of Set 5 | deyang
# Processing Record 27 of Set 5 | goundam
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | belmonte
# Processing Record 30 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 5 | hervey bay
# Processing Record 32 of Set 5 | souillac
# Processing Record 33 of Set 5 | bati
# Processing Record 34 of Set 5 | antsohihy
# Processing Record 35 of Set 5 | partizanskoye
# Processing Record 36 of Set 5 | shu
# Processing Record 37 of Set 5 | saint-pierre
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | makakilo city
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | baghdad
# Processing Record 42 of Set 5 | gushikawa
# Processing Record 43 of Set 5 | murwara
# Processing Record 44 of Set 5 | chuy
# Processing Record 45 of Set 5 | honiara
# Processing Record 46 of Set 5 | ormara
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | taihe
# Processing Record 49 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 50 of Set 5 | auka
# Processing Record 1 of Set 6 | xai-xai
# Processing Record 2 of Set 6 | gumdag
# Processing Record 3 of Set 6 | hofn
# Processing Record 4 of Set 6 | bentong
# Processing Record 5 of Set 6 | soyo
# Processing Record 6 of Set 6 | moron
# Processing Record 7 of Set 6 | odienne
# Processing Record 8 of Set 6 | castro
# Processing Record 9 of Set 6 | marawi
# Processing Record 10 of Set 6 | fuyu
# Processing Record 11 of Set 6 | iringa
# Processing Record 12 of Set 6 | upington
# Processing Record 13 of Set 6 | nanortalik
# Processing Record 14 of Set 6 | prado
# Processing Record 15 of Set 6 | pitimbu
# Processing Record 16 of Set 6 | tocopilla
# Processing Record 17 of Set 6 | yokadouma
# Processing Record 18 of Set 6 | nizhniy kuranakh
# Processing Record 19 of Set 6 | lata
# Processing Record 20 of Set 6 | slave lake
# Processing Record 21 of Set 6 | burnie
# Processing Record 22 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 6 | kushima
# Processing Record 24 of Set 6 | veraval
# Processing Record 25 of Set 6 | ulaanbaatar
# Processing Record 26 of Set 6 | vikhorevka
# Processing Record 27 of Set 6 | sao felix do xingu
# Processing Record 28 of Set 6 | klamath falls
# Processing Record 29 of Set 6 | solnechnyy
# Processing Record 30 of Set 6 | ribeira brava
# Processing Record 31 of Set 6 | tomelloso
# Processing Record 32 of Set 6 | ca mau
# Processing Record 33 of Set 6 | biloela
# Processing Record 34 of Set 6 | nioro
# Processing Record 35 of Set 6 | aklavik
# Processing Record 36 of Set 6 | gollere
# City not found. Skipping...
# Processing Record 37 of Set 6 | mantsala
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 6 | shitanjing
# Processing Record 41 of Set 6 | brea
# Processing Record 42 of Set 6 | wajima
# Processing Record 43 of Set 6 | rudsar
# Processing Record 44 of Set 6 | vung tau
# Processing Record 45 of Set 6 | kahului
# Processing Record 46 of Set 6 | ust-kuyga
# Processing Record 47 of Set 6 | manakara
# Processing Record 48 of Set 6 | cayenne
# Processing Record 49 of Set 6 | brodnica
# Processing Record 50 of Set 6 | egvekinot
# Processing Record 1 of Set 7 | atasu
# Processing Record 2 of Set 7 | matara
# Processing Record 3 of Set 7 | kruisfontein
# Processing Record 4 of Set 7 | saint-augustin
# Processing Record 5 of Set 7 | oranjemund
# Processing Record 6 of Set 7 | cumpas
# Processing Record 7 of Set 7 | tuatapere
# Processing Record 8 of Set 7 | aplahoue
# Processing Record 9 of Set 7 | hami
# Processing Record 10 of Set 7 | ternate
# Processing Record 11 of Set 7 | patiya
# Processing Record 12 of Set 7 | prince rupert
# Processing Record 13 of Set 7 | jumla
# Processing Record 14 of Set 7 | gornopravdinsk
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | batsfjord
# Processing Record 17 of Set 7 | khatanga
# Processing Record 18 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 7 | kurya
# Processing Record 20 of Set 7 | baillif
# Processing Record 21 of Set 7 | norman wells
# Processing Record 22 of Set 7 | saint-denis
# Processing Record 23 of Set 7 | homer
# Processing Record 24 of Set 7 | severo-kurilsk
# Processing Record 25 of Set 7 | okhotsk
# Processing Record 26 of Set 7 | copiapo
# Processing Record 27 of Set 7 | kanor
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | numan
# Processing Record 30 of Set 7 | barabai
# Processing Record 31 of Set 7 | port hedland
# Processing Record 32 of Set 7 | portland
# Processing Record 33 of Set 7 | rio cuarto
# Processing Record 34 of Set 7 | ypsilanti
# Processing Record 35 of Set 7 | zambezi
# Processing Record 36 of Set 7 | kamaishi
# Processing Record 37 of Set 7 | miri
# Processing Record 38 of Set 7 | bara
# Processing Record 39 of Set 7 | danshui
# Processing Record 40 of Set 7 | hay river
# Processing Record 41 of Set 7 | la primavera
# Processing Record 42 of Set 7 | moa
# Processing Record 43 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 7 | nongstoin
# Processing Record 45 of Set 7 | toora-khem
# Processing Record 46 of Set 7 | matrei
# City not found. Skipping...
# Processing Record 47 of Set 7 | mahebourg
# Processing Record 48 of Set 7 | miguel hidalgo
# Processing Record 49 of Set 7 | moncton
# Processing Record 50 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 1 of Set 8 | kaliua
# Processing Record 2 of Set 8 | ipira
# Processing Record 3 of Set 8 | raisinghnagar
# Processing Record 4 of Set 8 | phonhong
# Processing Record 5 of Set 8 | chapais
# Processing Record 6 of Set 8 | constitucion
# Processing Record 7 of Set 8 | san ignacio
# Processing Record 8 of Set 8 | kundiawa
# Processing Record 9 of Set 8 | samarai
# Processing Record 10 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 8 | kamsack
# Processing Record 12 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 8 | temerloh
# Processing Record 15 of Set 8 | pangnirtung
# Processing Record 16 of Set 8 | kisangani
# Processing Record 17 of Set 8 | los llanos de aridane
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | tateyama
# Processing Record 20 of Set 8 | vila do maio
# Processing Record 21 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 8 | leningradskiy
# Processing Record 23 of Set 8 | ponta delgada
# Processing Record 24 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 8 | la romana
# Processing Record 27 of Set 8 | college
# Processing Record 28 of Set 8 | ostrovnoy
# Processing Record 29 of Set 8 | rio gallegos
# Processing Record 30 of Set 8 | spornoye
# Processing Record 31 of Set 8 | torbat-e jam
# Processing Record 32 of Set 8 | kasongo-lunda
# Processing Record 33 of Set 8 | kiunga
# Processing Record 34 of Set 8 | hamilton
# Processing Record 35 of Set 8 | vila franca do campo
# Processing Record 36 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 8 | bulungu
# Processing Record 38 of Set 8 | arona
# Processing Record 39 of Set 8 | reconquista
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | cherkasskoye
# Processing Record 42 of Set 8 | kodinsk
# Processing Record 43 of Set 8 | gravdal
# Processing Record 44 of Set 8 | spearfish
# Processing Record 45 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 8 | prabumulih
# Processing Record 47 of Set 8 | pacific grove
# Processing Record 48 of Set 8 | aykhal
# Processing Record 49 of Set 8 | namibe
# Processing Record 50 of Set 8 | mandera
# Processing Record 1 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 2 of Set 9 | auki
# Processing Record 3 of Set 9 | ghatsila
# Processing Record 4 of Set 9 | bujaru
# Processing Record 5 of Set 9 | carnarvon
# Processing Record 6 of Set 9 | san luis
# Processing Record 7 of Set 9 | coruripe
# Processing Record 8 of Set 9 | ishigaki
# Processing Record 9 of Set 9 | havre-saint-pierre
# Processing Record 10 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 9 | riberalta
# Processing Record 12 of Set 9 | nokaneng
# Processing Record 13 of Set 9 | umaria
# Processing Record 14 of Set 9 | lompoc
# Processing Record 15 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 16 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 17 of Set 9 | acapulco
# Processing Record 18 of Set 9 | vestmannaeyjar
# Processing Record 19 of Set 9 | vestmanna
# Processing Record 20 of Set 9 | mwanza
# Processing Record 21 of Set 9 | hermiston
# Processing Record 22 of Set 9 | pisco
# Processing Record 23 of Set 9 | biak
# Processing Record 24 of Set 9 | itoman
# Processing Record 25 of Set 9 | ancud
# Processing Record 26 of Set 9 | china
# Processing Record 27 of Set 9 | baiyin
# Processing Record 28 of Set 9 | mahajanga
# Processing Record 29 of Set 9 | chaman
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | utete
# Processing Record 32 of Set 9 | moosomin
# Processing Record 33 of Set 9 | guanare
# Processing Record 34 of Set 9 | esperance
# Processing Record 35 of Set 9 | halifax
# Processing Record 36 of Set 9 | beidao
# Processing Record 37 of Set 9 | praia da vitoria
# Processing Record 38 of Set 9 | ayorou
# Processing Record 39 of Set 9 | yumen
# Processing Record 40 of Set 9 | srednekolymsk
# Processing Record 41 of Set 9 | bowmore
# Processing Record 42 of Set 9 | bitburg
# Processing Record 43 of Set 9 | yangjiang
# Processing Record 44 of Set 9 | nizwa
# Processing Record 45 of Set 9 | bilma
# Processing Record 46 of Set 9 | hurghada
# Processing Record 47 of Set 9 | yulara
# Processing Record 48 of Set 9 | belyy yar
# Processing Record 49 of Set 9 | qaqortoq
# Processing Record 50 of Set 9 | bilibino
# Processing Record 1 of Set 10 | victoria
# Processing Record 2 of Set 10 | ondjiva
# Processing Record 3 of Set 10 | fort nelson
# Processing Record 4 of Set 10 | gwanda
# Processing Record 5 of Set 10 | balad
# Processing Record 6 of Set 10 | faya
# Processing Record 7 of Set 10 | kumbo
# Processing Record 8 of Set 10 | henties bay
# Processing Record 9 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 10 | saint peter
# Processing Record 11 of Set 10 | nador
# Processing Record 12 of Set 10 | kokopo
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | mabaruma
# Processing Record 15 of Set 10 | pathein
# Processing Record 16 of Set 10 | carnot
# Processing Record 17 of Set 10 | goba
# Processing Record 18 of Set 10 | touros
# Processing Record 19 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 10 | evensk
# Processing Record 21 of Set 10 | arman
# Processing Record 22 of Set 10 | tyrma
# Processing Record 23 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 10 | khao yoi
# Processing Record 25 of Set 10 | kerema
# Processing Record 26 of Set 10 | kigorobya
# Processing Record 27 of Set 10 | kigoma
# Processing Record 28 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 29 of Set 10 | marsa matruh
# Processing Record 30 of Set 10 | matipo
# Processing Record 31 of Set 10 | trabzon
# Processing Record 32 of Set 10 | aden
# Processing Record 33 of Set 10 | sambava
# Processing Record 34 of Set 10 | yagodnoye
# Processing Record 35 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 10 | bridlington
# Processing Record 37 of Set 10 | port augusta
# Processing Record 38 of Set 10 | tupik
# Processing Record 39 of Set 10 | san quintin
# Processing Record 40 of Set 10 | leeton
# Processing Record 41 of Set 10 | lorengau
# Processing Record 42 of Set 10 | xixiang
# Processing Record 43 of Set 10 | port blair
# Processing Record 44 of Set 10 | lyudinovo
# Processing Record 45 of Set 10 | tarko-sale
# Processing Record 46 of Set 10 | dondo
# Processing Record 47 of Set 10 | asyut
# Processing Record 48 of Set 10 | north las vegas
# Processing Record 49 of Set 10 | healdsburg
# Processing Record 50 of Set 10 | ha giang
# Processing Record 1 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 11 | moranbah
# Processing Record 3 of Set 11 | atar
# Processing Record 4 of Set 11 | bathsheba
# Processing Record 5 of Set 11 | ahtopol
# Processing Record 6 of Set 11 | north bend
# Processing Record 7 of Set 11 | livingston
# Processing Record 8 of Set 11 | iskateley
# Processing Record 9 of Set 11 | broken hill
# Processing Record 10 of Set 11 | komsomolskiy
# Processing Record 11 of Set 11 | vao
# Processing Record 12 of Set 11 | mahanoro
# Processing Record 13 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 11 | innisfail
# Processing Record 16 of Set 11 | fethiye
# Processing Record 17 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 11 | novolabinskaya
# Processing Record 19 of Set 11 | inuvik
# Processing Record 20 of Set 11 | yilan
# Processing Record 21 of Set 11 | pichayevo
# Processing Record 22 of Set 11 | ellsworth
# Processing Record 23 of Set 11 | mandeville
# Processing Record 24 of Set 11 | nakambala
# Processing Record 25 of Set 11 | verkhnyaya toyma
# Processing Record 26 of Set 11 | sibolga
# Processing Record 27 of Set 11 | moyale
# Processing Record 28 of Set 11 | kilrush
# Processing Record 29 of Set 11 | asfi
# Processing Record 30 of Set 11 | verkhnevilyuysk
# Processing Record 31 of Set 11 | batagay
# Processing Record 32 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 33 of Set 11 | mandalgovi
# Processing Record 34 of Set 11 | sirjan
# Processing Record 35 of Set 11 | mangochi
# Processing Record 36 of Set 11 | birjand
# Processing Record 37 of Set 11 | galway
# Processing Record 38 of Set 11 | broome
# Processing Record 39 of Set 11 | san cristobal
# Processing Record 40 of Set 11 | puerto madero
# Processing Record 41 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 11 | praia
# Processing Record 43 of Set 11 | areka
# Processing Record 44 of Set 11 | poronaysk
# Processing Record 45 of Set 11 | chumphon
# Processing Record 46 of Set 11 | inhambane
# Processing Record 47 of Set 11 | wattegama
# Processing Record 48 of Set 11 | independencia
# Processing Record 49 of Set 11 | dehloran
# Processing Record 50 of Set 11 | sola
# Processing Record 1 of Set 12 | vanavara
# Processing Record 2 of Set 12 | arbazh
# Processing Record 3 of Set 12 | luis correia
# Processing Record 4 of Set 12 | camacha
# Processing Record 5 of Set 12 | karratha
# Processing Record 6 of Set 12 | guadalupe victoria
# Processing Record 7 of Set 12 | arlit
# Processing Record 8 of Set 12 | kurtalan
# Processing Record 9 of Set 12 | codrington
# Processing Record 10 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 12 | nemuro
# Processing Record 12 of Set 12 | burgeo
# Processing Record 13 of Set 12 | concepcion del uruguay
# Processing Record 14 of Set 12 | manaus
# Processing Record 15 of Set 12 | hambantota
# Processing Record 16 of Set 12 | dicabisagan
# Processing Record 17 of Set 12 | manaure
# Processing Record 18 of Set 12 | williams lake
# Processing Record 19 of Set 12 | mahon
# Processing Record 20 of Set 12 | haines junction
# Processing Record 21 of Set 12 | hirara
# Processing Record 22 of Set 12 | belaya gora
# Processing Record 23 of Set 12 | maceio
# Processing Record 24 of Set 12 | ossora
# Processing Record 25 of Set 12 | iwanai
# Processing Record 26 of Set 12 | wagar
# Processing Record 27 of Set 12 | santa isabel do rio negro
# Processing Record 28 of Set 12 | taiyuan
# Processing Record 29 of Set 12 | valledupar
# Processing Record 30 of Set 12 | ust-nera
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | mirpur mathelo
# Processing Record 33 of Set 12 | cilegon
# Processing Record 34 of Set 12 | dong hoi
# Processing Record 35 of Set 12 | riyadh
# Processing Record 36 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | midland
# Processing Record 39 of Set 12 | wadi musa
# Processing Record 40 of Set 12 | mvangue
# Processing Record 41 of Set 12 | jidong
# Processing Record 42 of Set 12 | kaeo
# Processing Record 43 of Set 12 | yabelo
# Processing Record 44 of Set 12 | valencia
# Processing Record 45 of Set 12 | rigaud
# Processing Record 46 of Set 12 | waw
# Processing Record 47 of Set 12 | pocatello
# Processing Record 48 of Set 12 | caravelas
# Processing Record 49 of Set 12 | flin flon
# Processing Record 50 of Set 12 | changji
# Processing Record 1 of Set 13 | matay
# Processing Record 2 of Set 13 | martapura
# Processing Record 3 of Set 13 | altonia
# City not found. Skipping...
# Processing Record 4 of Set 13 | terpinnya
# Processing Record 5 of Set 13 | uyuni
# Processing Record 6 of Set 13 | gunjur
# Processing Record 7 of Set 13 | manzhouli
# Processing Record 8 of Set 13 | chenzhou
# Processing Record 9 of Set 13 | susanville
# Processing Record 10 of Set 13 | gurupa
# Processing Record 11 of Set 13 | kalevala
# Processing Record 12 of Set 13 | yatou
# Processing Record 13 of Set 13 | mitsamiouli
# Processing Record 14 of Set 13 | talnakh
# Processing Record 15 of Set 13 | maiduguri
# Processing Record 16 of Set 13 | ludvika
# Processing Record 17 of Set 13 | shar
# Processing Record 18 of Set 13 | urman
# Processing Record 19 of Set 13 | bandarbeyla
# Processing Record 20 of Set 13 | saint-joseph
# Processing Record 21 of Set 13 | umm bab
# Processing Record 22 of Set 13 | faranah
# Processing Record 23 of Set 13 | kysyl-syr
# Processing Record 24 of Set 13 | harper
# Processing Record 25 of Set 13 | tura
# Processing Record 26 of Set 13 | havelock
# Processing Record 27 of Set 13 | palauig
# Processing Record 28 of Set 13 | half moon bay
# Processing Record 29 of Set 13 | itaquyry
# Processing Record 30 of Set 13 | sao filipe
# Processing Record 31 of Set 13 | sychevka
# Processing Record 32 of Set 13 | wad madani
# Processing Record 33 of Set 13 | huntington beach
# Processing Record 34 of Set 13 | xuddur
# Processing Record 35 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 13 | rambha
# Processing Record 37 of Set 13 | trincomalee
# Processing Record 38 of Set 13 | vallenar
# Processing Record 39 of Set 13 | mwinilunga
# Processing Record 40 of Set 13 | saint-louis
# Processing Record 41 of Set 13 | bonfim
# Processing Record 42 of Set 13 | dombas
# Processing Record 43 of Set 13 | cockburn town
# Processing Record 44 of Set 13 | palmer
# Processing Record 45 of Set 13 | tiznit
# Processing Record 46 of Set 13 | mana
# Processing Record 47 of Set 13 | kirakira
# Processing Record 48 of Set 13 | urumqi
# Processing Record 49 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 13 | panji
# Processing Record 1 of Set 14 | alyangula
# Processing Record 2 of Set 14 | fairbanks
# Processing Record 3 of Set 14 | gresham
# Processing Record 4 of Set 14 | alipur
# Processing Record 5 of Set 14 | kambove
# Processing Record 6 of Set 14 | balykshi
# Processing Record 7 of Set 14 | tashla
# Processing Record 8 of Set 14 | biltine
# Processing Record 9 of Set 14 | lovozero
# Processing Record 10 of Set 14 | sakakah
# Processing Record 11 of Set 14 | nipawin
# Processing Record 12 of Set 14 | ati
# Processing Record 13 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 14 | ystad
# Processing Record 15 of Set 14 | mirnyy
# Processing Record 16 of Set 14 | eenhana
# Processing Record 17 of Set 14 | quang ngai
# Processing Record 18 of Set 14 | kibre mengist
# Processing Record 19 of Set 14 | sandwick
# Processing Record 20 of Set 14 | brenham
# Processing Record 21 of Set 14 | sept-iles
# Processing Record 22 of Set 14 | meadow lake
# Processing Record 23 of Set 14 | koutiala
# Processing Record 24 of Set 14 | kamien pomorski
# Processing Record 25 of Set 14 | shingu
# Processing Record 26 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 14 | byron bay
# Processing Record 28 of Set 14 | chapleau
# Processing Record 29 of Set 14 | victor harbor
# Processing Record 30 of Set 14 | mayo
# Processing Record 31 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 33 of Set 14 | zhangjiakou
# Processing Record 34 of Set 14 | rosita
# Processing Record 35 of Set 14 | ergani
# Processing Record 36 of Set 14 | orotukan
# Processing Record 37 of Set 14 | swift current
# Processing Record 38 of Set 14 | vyazma
# Processing Record 39 of Set 14 | modasa
# Processing Record 40 of Set 14 | lipari
# Processing Record 41 of Set 14 | bud
# Processing Record 42 of Set 14 | fuerte olimpo
# Processing Record 43 of Set 14 | barranca
# Processing Record 44 of Set 14 | paita
# Processing Record 45 of Set 14 | kalulushi
# Processing Record 46 of Set 14 | cumra
# Processing Record 47 of Set 14 | zaozerne
# Processing Record 48 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 14 | chahal
# Processing Record 50 of Set 14 | isetskoye
# Processing Record 1 of Set 15 | prainha
# Processing Record 2 of Set 15 | alice springs
# Processing Record 3 of Set 15 | isangel
# Processing Record 4 of Set 15 | gorontalo
# Processing Record 5 of Set 15 | hammerfest
# Processing Record 6 of Set 15 | nara
# Processing Record 7 of Set 15 | kishapu
# Processing Record 8 of Set 15 | ahar
# Processing Record 9 of Set 15 | la palma
# Processing Record 10 of Set 15 | lowestoft
# Processing Record 11 of Set 15 | lysyye gory
# Processing Record 12 of Set 15 | black river
# Processing Record 13 of Set 15 | hualmay
# Processing Record 14 of Set 15 | soltsy
# Processing Record 15 of Set 15 | frontera
# Processing Record 16 of Set 15 | kirovsk
# Processing Record 17 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 15 | manokwari
# Processing Record 19 of Set 15 | ust-maya
# Processing Record 20 of Set 15 | diu
# Processing Record 21 of Set 15 | almeirim
# Processing Record 22 of Set 15 | lakewood
# Processing Record 23 of Set 15 | shipitsyno
# Processing Record 24 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 15 | manggar
# Processing Record 26 of Set 15 | kudahuvadhoo
# Processing Record 27 of Set 15 | rondonopolis
# Processing Record 28 of Set 15 | canillo
# Processing Record 29 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 15 | ola
# Processing Record 31 of Set 15 | marion
# Processing Record 32 of Set 15 | sturgeon bay
# Processing Record 33 of Set 15 | sarakhs
# Processing Record 34 of Set 15 | saint-georges
# Processing Record 35 of Set 15 | salta
# Processing Record 36 of Set 15 | smithers
# Processing Record 37 of Set 15 | galle
# Processing Record 38 of Set 15 | abu samrah
# Processing Record 39 of Set 15 | taguatinga
# Processing Record 40 of Set 15 | moses lake
# Processing Record 41 of Set 15 | asau
# Processing Record 42 of Set 15 | laurel
# Processing Record 43 of Set 15 | strelka
# Processing Record 44 of Set 15 | guangyuan
# Processing Record 45 of Set 15 | iraan
# Processing Record 46 of Set 15 | canning
# Processing Record 47 of Set 15 | banganapalle
# Processing Record 48 of Set 15 | ures
# Processing Record 49 of Set 15 | straumen
# Processing Record 50 of Set 15 | mahibadhoo
# Processing Record 1 of Set 16 | tucuma
# Processing Record 2 of Set 16 | lazaro cardenas
# Processing Record 3 of Set 16 | pimentel
# Processing Record 4 of Set 16 | ulaangom
# Processing Record 5 of Set 16 | laguna
# Processing Record 6 of Set 16 | zarubino
# Processing Record 7 of Set 16 | medea
# Processing Record 8 of Set 16 | mufumbwe
# Processing Record 9 of Set 16 | wufeng
# Processing Record 10 of Set 16 | poum
# Processing Record 11 of Set 16 | waingapu
# Processing Record 12 of Set 16 | stornoway
# Processing Record 13 of Set 16 | elk plain
# Processing Record 14 of Set 16 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 16 | olafsvik
# Processing Record 16 of Set 16 | zwedru
# Processing Record 17 of Set 16 | saint-francois
# Processing Record 18 of Set 16 | kenora
# Processing Record 19 of Set 16 | huescar
# Processing Record 20 of Set 16 | salatrucu
# Processing Record 21 of Set 16 | hokitika
# Processing Record 22 of Set 16 | kaitong
# Processing Record 23 of Set 16 | general roca
# Processing Record 24 of Set 16 | valinhos
# Processing Record 25 of Set 16 | oda
# Processing Record 26 of Set 16 | kanniyakumari
# Processing Record 27 of Set 16 | cap malheureux
# Processing Record 28 of Set 16 | matagami
# Processing Record 29 of Set 16 | beohari
# Processing Record 30 of Set 16 | huron
# Processing Record 31 of Set 16 | shache
# Processing Record 32 of Set 16 | baoying
# Processing Record 33 of Set 16 | kargasok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 715

# %%
# Add city data to new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town -33.9258   18.4232     59.11        79          20
# 1         Kaili  -3.4626  120.2147     68.41        87         100
# 2  Punta Arenas -53.1500  -70.9167     42.91        87          75
# 3     Norrtalje  59.7580   18.7050     39.02        79           0
# 4         Sitka  57.0531 -135.3300     48.09        76         100
#
#    Wind Speed Country Current Description
# 0        8.05      ZA          few clouds
# 1        3.20      ID       moderate rain
# 2        6.91      CL       broken clouds
# 3        8.08      SE           clear sky
# 4        0.00      US          light rain

# %%
# Reorder columns
new_column_order = ['City', 'Country','Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Cape Town      ZA -33.9258   18.4232     59.11        79          20
# 1           Kaili      ID  -3.4626  120.2147     68.41        87         100
# 2    Punta Arenas      CL -53.1500  -70.9167     42.91        87          75
# 3       Norrtalje      SE  59.7580   18.7050     39.02        79           0
# 4           Sitka      US  57.0531 -135.3300     48.09        76         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 710       Beohari      IN  24.0500   81.3833     83.77        16          71
# 711         Huron      US  41.1501  -82.5499     81.86        51         100
# 712        Shache      CN  38.4167   77.2406     69.67        20          24
# 713       Baoying      CN  33.2292  119.3092     60.84        96         100
# 714      Kargasok      RU  59.0556   80.8572     27.14        84         100
#
#      Wind Speed Current Description
# 0          8.05          few clouds
# 1          3.20       moderate rain
# 2          6.91       broken clouds
# 3          8.08           clear sky
# 4          0.00          light rain
# ..          ...                 ...
# 710        3.94       broken clouds
# 711       17.16     overcast clouds
# 712       15.10          few clouds
# 713       10.27     overcast clouds
# 714        7.83     overcast clouds
#
# [715 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
